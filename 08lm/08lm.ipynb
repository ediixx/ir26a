# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("api_key")

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="¿Cuándo nació Cristóbal Colón?"
)

print(response.text)
# Out:
# La fecha de nacimiento de Cristóbal Colón no se conoce con total certeza debido a la escasez de registros definitivos de la época. Sin embargo, la mayoría de los historiadores coinciden en que nació entre el **25 de agosto y el 31 de octubre de 1451**.
#
# A menudo, simplemente se cita el **año 1451** como el de su nacimiento.
